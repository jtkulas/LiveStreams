# %% [markdown]
# # R is for <br>Authoring!!
#
# OOH Session #94…<br> <span class="orbitron">…D2
# Diagrams<sup><u>version2</u></sup><br>(with a little too)</span>
#
# ## Open Office Hours <br>(September 12, 2025)
#
# <table>
# <colgroup>
# <col style="width: 90%" />
# <col style="width: 10%" />
# </colgroup>
# <tbody>
# <tr>
# <td style="text-align: left;"><div class="first-column" width="90.0%"
# data-layout-align="left">
# <ul>
# <li>Recap session #93</li>
# <li>Focal issue(s):
# <ul>
# <li><a href="https://d2lang.com/blog/"><span class="orbitron">…D2
# Diagrams <sup><u>version2</u></sup></span></a></li>
# </ul></li>
# <li>Shared problem-solving</li>
# </ul>
# </div></td>
# <td style="text-align: left;"><div class="second-column" width="10.0%"
# data-layout-align="left">
# &#10;</div></td>
# </tr>
# </tbody>
# </table>
#
# ![](attachment:img/title93.JPG){ .absolute top="185" right="-120" width="550"}
#
# ![](https://static.vecteezy.com/system/resources/previews/015/241/249/non_2x/glowing-neon-arrow-doodle-transparent-free-png.png){ .absolute top="160" left="370" width="200"}
#
# # Recap of Session <br>#93:
#
# ![](https://pngimg.com/d/sticky_note_PNG18964.png){ .absolute right="50" top="200"}
#
# ![](https://media.giphy.com/media/v1.Y2lkPTc5MGI3NjExMzRnbjhjNDhhNmJndTlzOXNyejc2MndnaDhsaDJkd3A1YmRhMm1rZSZlcD12MV9naWZzX3NlYXJjaCZjdD1n/H54feNXf6i4eAQubud/giphy.gif){ .absolute width="120" top="270" right="115"}
#
# ##
#
# # Today…
#
# ![](https://media2.giphy.com/media/v1.Y2lkPTc5MGI3NjExeHFla2luMzQ0aG5iOHZ6Y2NiYjY5NWhoYTZuMTFqMHdmeHU2cnZudCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/8OJdqYqN1Nii3UTD6l/giphy.gif)
#
# ## [<span class="orbitron">…D2 Diagrams</span>](https://d2lang.com/tour/shapes/) [via ](https://github.com/data-intuitive/quarto-d2) [<span class="orbitron"><sup><u>(version2)</u></sup></span>](https://elipousson.github.io/d2r/)
#
# ![](https://elipousson.github.io/d2r/reference/figures/README-connected_diagram.png){ .absolute height="400" left="100"}
#
# ![](https://www.freeiconspng.com/uploads/number-2-icon-11.png){ .absolute .tilt2 left="260" bottom="350" height="80"}
#
# ![](https://media0.giphy.com/media/v1.Y2lkPTc5MGI3NjExZnk5eXk5YzlqNmhmb2lucDhqb3JlbzI3ZHI1c2l3anVjNjh1emU2aCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/nopqz91prOyvS/giphy.gif){ .absolute right="-120" top="120" height="200"}
#
# ![](https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExZng5ZTRsdGZiZHJ5dGl2ZXc3bXMybWdnaGhqdHAzazVneHNxNzdqdiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/XQ1FwjRKun4nS/giphy.gif){ .absolute left="-90" bottom="40"}
#
# ![](https://media0.giphy.com/media/v1.Y2lkPTc5MGI3NjExeDF4NzlhNjFqcGpnbnR3ajVxbHF3cnd5aTg4cjdwYWhjbHI5ejk5ZSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/l0O2Q22fPpxR0zhba/giphy.gif){ .absolute right="-100" bottom="30"}
#
# ![](attachment:img/r2logo.png){ .absolute .mirror left="-80" top="120" height="200"}
#
# ## Laptop “breakthrough”:
#
# 1.  Download & “run” [`*.msi`
#     option](https://github.com/terrastruct/d2/releases)[1]
# 2.  Find Application
# 3.  Create project folder (within )
# 4.  Cut Application & locate within project folder
# 5.  Use [example script with YAML
#     specs](https://github.com/data-intuitive/quarto-d2?tab=readme-ov-file#global-options)
#
# > **Note**
# >
# > Also [see Playground
# > ](https://play.d2lang.com/?script=qlDQtVOoBBFRXIAAAAD__w%3D%3D&)
#
# ``` r
# #| label: gonnaembed
# #| echo: true
# #| eval: false
#
# ---
# title: "D2 Example"
# filters:
#   - d2
# d2:
#   layout: elk
#   theme: "GrapeSoda"
# ---
#
# Check out the neat diagram:
#
# ``{.d2 width="40%" echo=true}
# x -> y -> z
# ``
# ```
#
# ![](https://www.freeiconspng.com/uploads/curved-arrow-black-png-0.png){ .absolute left="370" top="450" height="150"}
#
# ![](https://www.pngkey.com/png/full/341-3414219_star-wars-3d-wall-nightlight-r2d2-white.png){ .absolute .tilt right="-120" top="170" height="350"}
#
# ## <sup>(2)</sup> Session Info (September 12, 2025) Rendering:
#
# [1] should be Windows compatible

# %%
sessionInfo()
# Out:
# R version 4.5.0 (2025-04-11 ucrt)
# Platform: x86_64-w64-mingw32/x64
# Running under: Windows 10 x64 (build 19045)
#
# Matrix products: default
#   LAPACK version 3.12.1
#
# locale:
# [1] LC_COLLATE=English_United States.utf8
# [2] LC_CTYPE=English_United States.utf8
# [3] LC_MONETARY=English_United States.utf8
# [4] LC_NUMERIC=C
# [5] LC_TIME=English_United States.utf8
#
# time zone: America/Chicago
# tzcode source: internal
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# loaded via a namespace (and not attached):
#  [1] compiler_4.5.0    fastmap_1.2.0     cli_3.6.5         tools_4.5.0
#  [5] htmltools_0.5.8.1 rstudioapi_0.17.1 yaml_2.3.10       rmarkdown_2.29
#  [9] knitr_1.50        jsonlite_2.0.0    xfun_0.52         digest_0.6.37
# [13] rlang_1.1.6       evaluate_1.0.4
